# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

import matplotlib as plt
import seaborn as sns

# %%
# Load Data
df = pd.read_csv('../../data/raw/Data_Merged_Final_Terbaru.csv')
df.head()
# Out:
#       video_id                                        Judul video  \
# 0  jkL6Ii5d4hI  SURPRISE! PASUKAN CHECHNYA SIAP TEMPUR BELA IN...
# 1  mIeRGD4KT-A  BUNGKAM MULUT AUSTRALIA! RUSIA ANCAM AUSTRALIA...
# 2  XCRg3dGQqd8  GEMPUR JEPANG & KOREA‼️ QRIS INDONESIA BIKIN M...
# 3  ej_cl5Ixy8I  RAJA JIPLAK ASEAN KALAH TELAK! PAMERAN INDONES...
# 4  _a-qHV6XZzE  AUSTRALIA ANCAM PERANG INDONESIA, JIKA RUSIA B...
#
#   Waktu publikasi video  Durasi  Penayangan tak dilewati  \
# 0          May 23, 2025   541.0                   436273
# 1           May 7, 2025   540.0                   379446
# 2           May 3, 2025   637.0                   348698
# 3           May 3, 2025   530.0                   332566
# 4          May 12, 2025   540.0                   329562
#
#    Pendapatan transaksi (IDR)  Estimasi pendapatan AdSense (IDR)  \
# 0                         0.0                        1005756.693
# 1                         0.0                        1079707.160
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2369 entries, 0 to 2368
# Data columns (total 57 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   video_id                                           2369 non-null   str
#  1   Judul video                                        2369 non-null   str
#  2   Waktu publikasi video                              2369 non-null   str
#  3   Durasi                                             2369 non-null   float64
#  4   Penayangan tak dilewati                            2369 non-null   int64
#  5   Pendapatan transaksi (IDR)                         2369 non-null   float64
#  6   Estimasi pendapatan AdSense (IDR)                  2369 non-null   float64
#  7   Estimasi pendapatan DoubleClick (IDR)              2369 non-null   int64
#  8   Subscriber yang diperoleh                          2369 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# video_id                                                0
# Judul video                                             0
# Waktu publikasi video                                   0
# Durasi                                                  0
# Penayangan tak dilewati                                 0
# Pendapatan transaksi (IDR)                              0
# Estimasi pendapatan AdSense (IDR)                       0
# Estimasi pendapatan DoubleClick (IDR)                   0
# Subscriber yang diperoleh                               0
# Subscriber yang hilang                                  0
# Suka                                                    0
# Tidak suka                                              0
# Komentar ditambahkan                                    0
# Persentase penayangan rata-rata (%)                     0
# Tetap menonton (%)                                   2203
# Penonton unik                                        2369
# ...

# %%
# Tetap menonton (%)                                   2203
# Penonton unik                                        2369
# Penonton yang kembali                                2369
# Penonton baru                                        2369
# Penonton biasa                                       2369
# Penonton reguler                                     2369
# Klik per kartu yang ditampilkan (%)                  2368
# Pendapatan iklan YouTube (IDR)                        138
# Tayangan iklan                                        138
# CPM berbasis-pemutaran (IDR)                          138

# %%
kolom_hapus = [
    'Tetap menonton (%)',
    'Penonton unik',
    'Penonton yang kembali',
    'Penonton baru',
    'Penonton biasa',
    'Penonton reguler',
    'Klik per kartu yang ditampilkan (%)',
    'CPM berbasis-pemutaran (IDR)',
    'CPM',
    'Pendapatan Iklan',
    'Estimasi pemutaran yang dimonetisasi'
]
df = df.drop(columns=[kolom for kolom in kolom_hapus if kolom in df.columns])
print("Kolom berhasil dihapus.")
# Out:
# Kolom berhasil dihapus.

# %%
df.isnull().sum()
# Out:
# video_id                                                0
# Judul video                                             0
# Waktu publikasi video                                   0
# Durasi                                                  0
# Penayangan tak dilewati                                 0
# Pendapatan transaksi (IDR)                              0
# Estimasi pendapatan AdSense (IDR)                       0
# Estimasi pendapatan DoubleClick (IDR)                   0
# Subscriber yang diperoleh                               0
# Subscriber yang hilang                                  0
# Suka                                                    0
# Tidak suka                                              0
# Komentar ditambahkan                                    0
# Persentase penayangan rata-rata (%)                     0
# YouTube Premium (IDR)                                   0
# Iklan Halaman Tonton (IDR)                              0
# ...

# %%
pd.set_option('display.max_columns', None)
df_null_pendapatan = df[df['Title'].isnull()]
display(df_null_pendapatan)
# Out:
#          video_id                                        Judul video  \
# 32    Ses_RMUM6Ts  DIBEKING AUSTRALIA! CAP INDONESIA PENJAJAH! SE...
# 43    3CTkyQUrxzk  MALAYSIA KAGET! RI BANGUN PAPUA JADI MEGA PUAS...
# 62    O7OLD2msmjg  KRISIS PANGAN! INDONESIA PILUH AFRIKA DARIPADA...
# 89    P9uXk7o0IPI  ASING KAGET, BERAS JEPANG NAIK GILA-GILAAN! MA...
# 146   WWwoSEGrpx0  MALAYSIA MENYESAL! DITINGGAL PEKERJA INDONESIA...
# 149   ROvyEjl1kW4  SEMAKIN MEMANAS! INDONESIA-RUSIA TURUN TANGAN ...
# 193   7VrLBH8lYSE  MALAYSIA NGEMIS! MENTERINYA DATANGI BULOG BUAT...
# 210   GeTlfh9bfCQ  MALAYSIA SENANG HATI MENAMPUNG RATUSAN ROHINGY...
# 211   rFdLtaUbuNo  LAGI!! KAPAL MALAYSIA DI TANGKAP TNI AL! PRABO...
# 215   4RJVrNLRfIw  MALAYSIA KETERGANTUNGAN PEKERJA ASING‼️WARGA L...
# 407   MXZDRacbXSw  PARLEMEN MALAYSIA RIBUT LAGI‼️INDONESIA HANYA ...
# 474   IxmShTaZmio  MALAYSIA HINA OJEK DI INDONESIA! SEBUT CERMINA...
# 490   TI3SQytv5tg  LAGU KEBANGSAAN BAHRAIN DITERIAKI! PELATIH BAH...
# ...

# %% [markdown]
# # Penanganan null pada upload time
#
# - Menggunakan cara melihat baris sebelum dan sesudah upload time kemudian mengisi jam diantaranya dan menggunakan indikator pengisian modus time, dikarenakan bug di scrapp maka harus diisi!

# %%
# Cari nama kolom waktu upload yang tersedia
time_col = None
for candidate in ['upload_time_wib', 'Upload Time (WIB)', 'publish_time_wib']:
    if candidate in df.columns:
        time_col = candidate
        break

if time_col:
    df = df.rename(columns={time_col: 'upload_time_wib'})
    print(f"Kolom waktu upload ditemukan: '{time_col}' -> 'upload_time_wib'")
    print(df['upload_time_wib'].head())
else:
    print("Kolom waktu upload tidak ditemukan. Kolom yang tersedia:")
    print(df.columns.tolist())
# Out:
# Kolom waktu upload ditemukan: 'Upload Time (WIB)' -> 'upload_time_wib'
# 0    11:15:06
# 1    09:15:06
# 2    16:15:06
# 3    09:15:06
# 4    12:30:06
# Name: upload_time_wib, dtype: str

# %%
import pandas as pd
from datetime import datetime, timedelta

# 1. Cek jumlah null sebelum penanganan
print(f"Jumlah null upload_time_wib sebelum: {df['upload_time_wib'].isnull().sum()}")

# 2. Fungsi konversi string waktu ke menit (untuk interpolasi)
def time_to_minutes(t):
    if pd.isna(t):
        return None
    try:
        h, m, s = str(t).split(':')
        return int(h) * 60 + int(m)
    except:
        return None

def minutes_to_time(minutes):
    h = int(minutes) // 60
    m = int(minutes) % 60
    return f"{h:02d}:{m:02d}:06"

# 3. Konversi ke menit untuk memudahkan interpolasi
df['_time_minutes'] = df['upload_time_wib'].apply(time_to_minutes)

# 4. Interpolasi linier (rata-rata nilai sebelum dan sesudah)
df['_time_minutes'] = df['_time_minutes'].interpolate(method='linear')

# 5. Konversi kembali ke format HH:MM:SS
df['upload_time_wib'] = df['_time_minutes'].apply(
    lambda x: minutes_to_time(round(x)) if pd.notna(x) else None
)

# 6. Fallback: isi sisa null (jika ada di ujung awal/akhir) dengan modus
modus_time = df['upload_time_wib'].mode()[0]
null_count_before_mode = df['upload_time_wib'].isnull().sum()

if null_count_before_mode > 0:
    df['upload_time_wib'] = df['upload_time_wib'].fillna(modus_time)
    print(f"  → {null_count_before_mode} nilai diisi dengan modus: '{modus_time}'")

# 7. Hapus kolom bantu
df = df.drop(columns=['_time_minutes'])

# 8. Verifikasi hasil
print(f"Jumlah null upload_time_wib sesudah : {df['upload_time_wib'].isnull().sum()}")
print(f"Modus upload_time_wib               : {modus_time}")
print(df['upload_time_wib'].head(10))
# Out:
# Jumlah null upload_time_wib sebelum: 45
# Jumlah null upload_time_wib sesudah : 0
# Modus upload_time_wib               : 15:30:06
# 0    11:15:06
# 1    09:15:06
# 2    16:15:06
# 3    09:15:06
# 4    12:30:06
# 5    12:30:06
# 6    20:30:06
# 7    20:45:06
# 8    12:30:06
# 9    16:15:06
# Name: upload_time_wib, dtype: str

# %%
df.isnull().sum()
# Out:
# video_id                                                0
# Judul video                                             0
# Waktu publikasi video                                   0
# Durasi                                                  0
# Penayangan tak dilewati                                 0
# Pendapatan transaksi (IDR)                              0
# Estimasi pendapatan AdSense (IDR)                       0
# Estimasi pendapatan DoubleClick (IDR)                   0
# Subscriber yang diperoleh                               0
# Subscriber yang hilang                                  0
# Suka                                                    0
# Tidak suka                                              0
# Komentar ditambahkan                                    0
# Persentase penayangan rata-rata (%)                     0
# YouTube Premium (IDR)                                   0
# Iklan Halaman Tonton (IDR)                              0
# ...

# %%
kolom_hapus = [
    'clicks_per_end_screen_element_shown_pct'
]
df = df.drop(columns=[kolom for kolom in kolom_hapus if kolom in df.columns])
print("Kolom berhasil dihapus.")
# Out:
# Kolom berhasil dihapus.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2369 entries, 0 to 2368
# Data columns (total 48 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   video_id                                           2369 non-null   str
#  1   Judul video                                        2369 non-null   str
#  2   Waktu publikasi video                              2369 non-null   str
#  3   Durasi                                             2369 non-null   float64
#  4   Penayangan tak dilewati                            2369 non-null   int64
#  5   Pendapatan transaksi (IDR)                         2369 non-null   float64
#  6   Estimasi pendapatan AdSense (IDR)                  2369 non-null   float64
#  7   Estimasi pendapatan DoubleClick (IDR)              2369 non-null   int64
#  8   Subscriber yang diperoleh                          2369 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(13)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2369 entries, 0 to 2368
# Data columns (total 48 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   video_id                                           2369 non-null   str
#  1   Judul video                                        2369 non-null   str
#  2   Waktu publikasi video                              2369 non-null   str
#  3   Durasi                                             2369 non-null   float64
#  4   Penayangan tak dilewati                            2369 non-null   int64
#  5   Pendapatan transaksi (IDR)                         2369 non-null   float64
#  6   Estimasi pendapatan AdSense (IDR)                  2369 non-null   float64
#  7   Estimasi pendapatan DoubleClick (IDR)              2369 non-null   int64
#  8   Subscriber yang diperoleh                          2369 non-null   int64
# ...

# %%
import re

def to_snake_case(name):
    # Ganti spasi dan karakter khusus dengan underscore, lalu lowercase
    name = re.sub(r'[\s\-\(\)%]+', '_', name)
    name = re.sub(r'_+', '_', name)  # hilangkan underscore ganda
    return name.strip('_').lower()

df.columns = [to_snake_case(col) for col in df.columns]

print("✅ Semua kolom sudah dalam format snake_case:")
print(df.columns.tolist())
# Out:
# ✅ Semua kolom sudah dalam format snake_case:
# ...

# %%
# Pembersihan Duplikat & Emoji / Karakter Khusus
import re

# 1. Hapus Duplikat
jumlah_awal = len(df)
df.drop_duplicates(inplace=True)
jumlah_akhir = len(df)
print(f"✅ Duplikat berhasil dihapus. Baris awal: {jumlah_awal}, Baris setelah hapus duplikat: {jumlah_akhir} (Dihapus: {jumlah_awal - jumlah_akhir} baris)")

# 2. Hapus Emoji dan Karakter Khusus (seperti ‼️, dsb.)
def clean_text_from_emoji_and_symbols(text):
    if not isinstance(text, str):
        return text
    # Menghapus emoji, simbol variasi Unicode, dan karakter non-standar lainnya.
    # Hanya menyisakan huruf, angka, spasi, dan tanda baca standar.
    cleaned = re.sub(r'[^\w\s.,!?;:&%()\-+$/[\]{}"\']', '', text)
    # Ganti spasi ganda/lebih menjadi satu spasi saja
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    return cleaned

kolom_teks = ['judul_video', 'judul', 'title']
for col in kolom_teks:
    if col in df.columns:
        df[col] = df[col].apply(clean_text_from_emoji_and_symbols)
        print(f"✅ Kolom '{col}' telah dibersihkan dari emoji dan karakter khusus/non-standar.")

# Tampilkan sampel judul video setelah dibersihkan
print("\nSampel judul setelah pembersihan:")
print(df['judul_video'].head(10))
# Out:
# ✅ Duplikat berhasil dihapus. Baris awal: 2369, Baris setelah hapus duplikat: 2356 (Dihapus: 13 baris)
# ✅ Kolom 'judul_video' telah dibersihkan dari emoji dan karakter khusus/non-standar.
# ✅ Kolom 'judul' telah dibersihkan dari emoji dan karakter khusus/non-standar.
# ✅ Kolom 'title' telah dibersihkan dari emoji dan karakter khusus/non-standar.
#
# Sampel judul setelah pembersihan:
# 0    SURPRISE! PASUKAN CHECHNYA SIAP TEMPUR BELA IN...
# 1    BUNGKAM MULUT AUSTRALIA! RUSIA ANCAM AUSTRALIA...
# 2    GEMPUR JEPANG & KOREA QRIS INDONESIA BIKIN MAL...
# 3    RAJA JIPLAK ASEAN KALAH TELAK! PAMERAN INDONES...
# 4    AUSTRALIA ANCAM PERANG INDONESIA, JIKA RUSIA B...
# 5    PAPUA NUGINI KAGET DENGA KEMAJUAN DI PAPUA IND...
# 6    PUTIN NGAMUK! SIAPA BERANI SENTUH INDONESIA, S...
# 7    TIMOR LESTE PERINGATKAN PAPUA ! JANGAN PISAH D...
# 8    KEMARAHAN RUSIA TAK TERBENDUNG! AUSTRALIA AKAN...
# 9    WARNING KERAS! PUTIN BOCORKAN RENCANA AUSTRALI...
# Name: judul_video, dtype: str

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ambil hanya kolom numerik
df_numerik = df.select_dtypes(include=['number'])

# ── Langkah 1: Hitung jumlah outlier per kolom ──
print("=" * 55)
print(f"{'Kolom':<40} {'Outlier':>7} {'% dari data':>10}")
print("=" * 55)

outlier_summary = {}
for col in df_numerik.columns:
    Q1 = df_numerik[col].quantile(0.25)
    Q3 = df_numerik[col].quantile(0.75)
    IQR = Q3 - Q1
    batas_bawah = Q1 - 1.5 * IQR
    batas_atas  = Q3 + 1.5 * IQR
    
    jumlah_outlier = ((df_numerik[col] < batas_bawah) | (df_numerik[col] > batas_atas)).sum()
    persen = jumlah_outlier / len(df) * 100
    outlier_summary[col] = jumlah_outlier
    print(f"{col:<40} {jumlah_outlier:>7} {persen:>9.1f}%")

print("=" * 55)

# ── Langkah 2: Visualisasi Boxplot ──
cols_plot = [col for col in df_numerik.columns if outlier_summary[col] > 0]

n_cols = 3
n_rows = (len(cols_plot) + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, n_rows * 4))
axes = axes.flatten()

for i, col in enumerate(cols_plot):
    sns.boxplot(y=df[col], ax=axes[i], color='steelblue', flierprops=dict(marker='o', color='red', markersize=3))
    axes[i].set_title(col, fontsize=9)
    axes[i].set_xlabel('')

# Sembunyikan axes yang kosong
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.suptitle('Boxplot Deteksi Outlier (IQR Method)', fontsize=14, y=1.01)
plt.tight_layout()
plt.show()
# Out:
# ...
# Kolom                                    Outlier % dari data
# ...
# durasi                                       309      13.1%
# penayangan_tak_dilewati                      284      12.1%
# pendapatan_transaksi_idr                       6       0.3%
# estimasi_pendapatan_adsense_idr              286      12.1%
# estimasi_pendapatan_doubleclick_idr            0       0.0%
# subscriber_yang_diperoleh                    331      14.0%
# subscriber_yang_hilang                       270      11.5%
# suka                                         227       9.6%
# tidak_suka                                   287      12.2%
# komentar_ditambahkan                         250      10.6%
# persentase_penayangan_rata_rata              158       6.7%
# youtube_premium_idr                          312      13.2%
# iklan_halaman_tonton_idr                     286      12.1%
# pendapatan_iklan_youtube_idr                 265      11.2%
# tayangan_iklan                               278      11.8%
# ...

# %%
# Ekspor data yang sudah bersih
output_path = "../../data/cleaned/abis_cleaning.csv"
df.to_csv(output_path, index=False)
print(f"Data berhasil disimpan ke {output_path}")
print(f"Jumlah baris: {len(df)}, Jumlah kolom: {len(df.columns)}")
# Out:
# Data berhasil disimpan ke ../../data/cleaned/abis_cleaning.csv
# Jumlah baris: 2356, Jumlah kolom: 48
